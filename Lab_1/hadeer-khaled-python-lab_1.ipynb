# %% [markdown]
# ## 1- Ask the user to input a number and print whether the number is within the specified range (20-50)

# %% [markdown]
# * isdigit() is more restrictive and only considers the basic decimal digits
# * isnumeric() is more inclusive and considers a broader range of numeric characters.("²34" , "123½")

# %%
user_input = input("Enter a number: ").isdigit()
if not user_input:
    print("Invalid Number")
else:
    if (user_input >= 20 and user_input <= 50):
        print(f"The number {user_input} is  within the range 20-50")
    else:
        print(f"The number {user_input} is not within the range 20-50")
# Out:
# Enter a number:  h
# Invalid Number

# %% [markdown]
# ## 2- Write a two functions to calculate the area and the perimeter of a rectangle given its length and width.

# %%
def rectangle_perimeter(length , width):
    return 2 * (length + width)
    
def rectangle_area(length , width):
    return length * width

print(f"Rectangle Perimeter: {rectangle_perimeter(10 , 5)}")
print(f"Rectangle Area: {rectangle_area(10 , 5)}")
# Out:
# Rectangle Perimeter: 30
# Rectangle Area: 50

# %% [markdown]
# ## 3- Write a function receive two strings and concatenate them with two different methods.

# %%
def concate_1(str1, str2):
    return f"{str(str1)}{str(str2)}"

def concate_2(str1, str2):
    return  str(str1) + str(str2)

def concate_3(str1, str2):
    return  ''.join([str(str1) , str(str1) ])

print("Method 1:", concate_1("Hello", "World"))
print("Method 2:", concate_2("1", "2"))
print("Method 3:", concate_3("Hello", "World"))
# Out:
# Method 1: HelloWorld
# Method 2: 12
# Method 3: HelloHello

# %% [markdown]
# ## 4- Write a function receive list of values , square each element in a given list and return the squared list

# %%
def sqr_list(input_list):
    return [elem**2 for elem in input_list]

print("Squared List:", sqr_list( [1, 2, 3, 4, 5]))
# Out:
# Squared List: [1, 4, 9, 16, 25]

# %% [markdown]
# ## 5- Implement a program to merge two dictionaries and return the result

# %%
def dict_merge_inplace(dict1, dict2):
    for i in dict2.keys():
        dict1[i]=dict2[i]
    return dict1
        
def dict_merge(dict1 , dict2):
    return {**dict1, **dict2}

dict1 ={'key1': 1, 'key2': 2}
dict2 = {'key3': 3, 'key4': 4}

print("Method 1:", dict_merge_inplace(dict1,dict2 ))
print("Method 2:", dict_merge({'key1': 1, 'key2': 2}, {'key3': 3, 'key4': 4}))
# Out:
# Method 1: {'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4}
# Method 2: {'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4}

# %% [markdown]
# ## 6- Write a function receive two lists and merge them.

# %%
def merge_list_inplace(list_1, list_2):
    list_1.extend(list_2) 
    return list_1

list_1 = [1, 2]
list_2 = [3, 4]
print("Merged List:",  merge_list_inplace(list_1, list_2))

#  .copy() , append , for loops
# Out:
# Merged List: [1, 2, 3, 4]

# %% [markdown]
# ### 7- Write a function to check if these keys (job, card_number) exists in this dictionary {"name": "jone", "email": "jane@outlook.com", "age": 25,"job": "engineer", "address": "cairo, Egypt"}.

# %%
def dic_key_search(keys_list ,  dic):
    for key in keys_list: 
        if key in dic.keys():
            print(f"The key '{key}' exists in the dictionary.")
        else:
            print(f"The key '{key}' doesn't exist in the dictionary.")

dic = {"name": "jone", "email": "jane@outlook.com", "age": 25,"job": "engineer", "address": "cairo, Egypt"}
keys_list=["job" ,"card_number" ]
dic_key_search(keys_list ,  dic)
# Out:
# The key 'job' exists in the dictionary.
# The key 'card_number' doesn't exist in the dictionary.

# %% [markdown]
# ## 8- Write a program that calculates the sum of numbers from 1 to 100 using a loop and print the result

# %%
result = 0
for num in range(1, 101):
    result += num
print(result)
# Out:
# 5050

# %% [markdown]
# ## 9- Write a function to check if a given number is even or odd.

# %%
def even_odd_checker(number):
     return "Even" if number % 2 == 0 else "Odd"

num = 6
print(f"The number {num} is {even_odd_checker(num)}.")
# Out:
# The number 6 is Even.

# %% [markdown]
# ## 11- Write a function to check if a given string is a palindrome (reads the same backward as forward).

# %%
# original_string = "0123456789"
# reversed_string = original_string[5::-1]
# reversed_string = original_string[1:7:3]
# reversed_string = original_string[::-1]

# print("Original String:", original_string)
# print("Reversed String:", reversed_string)

# %%
def reverse(string):
    return string == string[::-1]

string_1 =  "haha"
string_2 =  "abccba"

print(f"Is {string} a palindrome ?", reverse(string_2))
# Out:
# Is haha a palindrome ? True

# %% [markdown]
# ## 12- Write a function that removes even numbers from a list and squares the remaining odd numbers.

# %%
def sqr_odd(input_list):
    squared_odd_numbers = []
    for num in input_list:
        if num % 2 != 0:
            squared_odd_numbers.append(num ** 2)

    return squared_odd_numbers

print(sqr_odd([1,2,3,4,5,6,7]))
# Out:
# [1, 9, 25, 49]

# %% [markdown]
# ## 13- Implement a function to check if a number is prime or not.

# %%
def prime_checker(num):
    for i in range(2, int(num/2) + 1):
        if num % i == 0:
            return False
    return True

num = 4;
print(f"Is {num} a prime number ?", prime_checker(num))
# Out:
# Is 4 a prime number ? False

# %% [markdown]
# ## 14- Write a function to calculate the factorial of a given number.

# %%
def factorial(num):
    if num < 0:
        return "Cannot calculate the factorial for negative numbers"
    elif num == 0 or num == 1:
        return 1
    else:
        res = 1
        for i in range(2, num + 1):
            res *= i
        return res
num = 5  
print(f"The factorial of {num} = ", factorial(num))
# Out:
# The factorial of 5 =  120

# %% [markdown]
# ## 15- Create a Python function that takes a list of numbers, performs various operations (sum, minimum, maximum, squared list), and returns a new list containing the results.

# %%
def sum_min_max_sqr(input_list):
    return [sum(input_list),min(input_list),max(input_list),[num ** 2 for num in input_list]]

print(" Sum = {} , Min = {} , Max = {} , Sqruared = {}".format( *sum_min_max_sqr([1, 2, 3, 4, 5])  ) )
# Out:
#  Sum = 15 , Min = 1 , Max = 5 , Sqruared = [1, 4, 9, 16, 25]

# %% [markdown]
# 1. Double Asterisk (**)
#
# * Function Keyword Argument Unpacking: In function definitions or calls, ** is used to unpack key-value pairs from a dictionary and pass them as keyword arguments.
# * Dictionary Unpacking: In dictionary unpacking, is used to unpack key-value pairs from one dictionary and include them in another.
#
# 2. Single Asterisk (*):
# * Function Argument Unpacking: In function definitions or calls, * is used to unpack the elements of an iterable (e.g., a list, tuple) and pass them as separate arguments.
# * Iterable Unpacking in Iterables: In iterable unpacking, * is used to unpack elements from one iterable and include them in another.
